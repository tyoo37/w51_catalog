# %%
# original file : https://github.com/keflavich/brick-jwst-2221/blob/main/brick2221/reduction/saturated_star_finding.py
import os
os.environ['STPSF_PATH'] = '/blue/adamginsburg/t.yoo/from_red/stpsf-data'
print(f"STPSF_PATH={os.environ['STPSF_PATH']}")
import glob
from astropy.io import fits
from scipy.ndimage import label, find_objects, center_of_mass, sum_labels
from astropy.modeling.fitting import LevMarLSQFitter
from jwst.datamodels import dqflags
import matplotlib.pyplot as plt
try:
    # version >=1.7.0, doesn't work: the PSF is broken (https://github.com/astropy/photutils/issues/1580?)
    from photutils.psf import PSFPhotometry, IterativePSFPhotometry, SourceGrouper
except:
    # version 1.6.0, which works
    from photutils.psf import BasicPSFPhotometry as PSFPhotometry, IterativelySubtractedPSFPhotometry as IterativePSFPhotometry, DAOGroup as SourceGrouper
try:
    from photutils.background import MMMBackground, MADStdBackgroundRMS, MedianBackground, Background2D, LocalBackground
except:
    from photutils.background import MMMBackground, MADStdBackgroundRMS, MedianBackground, Background2D
    from photutils.background import MMMBackground as LocalBackground


from tqdm.notebook import tqdm
from tqdm import tqdm
from astropy import wcs
from astropy.wcs import WCS
import numpy as np
from scipy import ndimage
from astropy.table import Table, QTable
from astropy import table
from astropy import log
from filtering import get_filtername, get_fwhm
import functools
import requests
import urllib3
def get_psf(header, path_prefix='.'):
    if header['INSTRUME'].lower() == 'nircam':
        psfgen = stpsf.NIRCam()
        fwhm, fwhm_pix = get_fwhm(header, instrument_replacement='NIRCam')
    elif header['INSTRUME'].lower() == 'miri':
        psfgen = stpsf.MIRI()
        fwhm, fwhm_pix = get_fwhm(header, instrument_replacement='MIRI')
    instrument = header['INSTRUME']
    filtername = get_filtername(header)
    try:
        module = header['MODULE']
    except KeyError:
        module = header['DETECTOR']
    detector = header['DETECTOR']

    ww = wcs.WCS(header)
    try:
        assert ww.wcs.cdelt[1] != 1, "This is not a valid WCS!!! CDELT is wrong!! how did this HAPPEN!?!?"
    except AssertionError as ex:
        print(ex)
        print("ignoring WCS failure so check that stuff is right...")

    psfgen.filter = filtername
    obsdate = header['DATE-OBS']

    with open(os.path.expanduser('~/.mast_api_token'), 'r') as fh:
        api_token = fh.read().strip()

    npsf = 16
    oversample = 2
    fov_pixels = 512
    if detector == 'NRCALONG':
        detector = 'nrca5'
    elif detector == 'NRCBLONG':
        detector = 'nrcb5'
    if detector.lower() == 'mirimage':
        detector = 'mirim'
    psf_fn = f'{path_prefix}/{instrument.lower()}_{detector.lower()}_{filtername.lower()}_fovp{fov_pixels}_samp{oversample}_npsf{npsf}.fits'

    if module == 'merged':
        project_id = header['PROGRAM'][1:5]
        obs_id = header['OBSERVTN'].strip()
        merged_psf_fn = f'{basepath}/psfs/{filtername.upper()}_{project_id}_{obs_id}_merged_PSFgrid.fits'
        if os.path.exists(psf_fn):
            psf_fn = merged_psf_fn
        else:
            print("stpsf is being used for merged data because merged PSF does not exist", flush=True)

    if os.path.exists(str(psf_fn)):
        # As a file
        log.info(f"Loading grid from psf_fn={psf_fn}")
        big_grid = to_griddedpsfmodel(psf_fn)  # file created 2 cells above
        if isinstance(big_grid, list):
            print(f"PSF IS A LIST OF GRIDS!!!", flush=True)
            big_grid = big_grid[0]
    else:
        log.info(f'PSF file {psf_fn} does not exist; downloading from MAST')
        from astroquery.mast import Mast

        print(f"Attempting to load PSF for {obsdate}")
        try:
            Mast.login(api_token.strip())
            os.environ['MAST_API_TOKEN'] = api_token.strip()

            psfgen.load_wss_opd_by_date(f'{obsdate}T00:00:00')
        except (urllib3.exceptions.ReadTimeoutError, requests.exceptions.ReadTimeout, requests.HTTPError) as ex:
            print(f"Failed to build PSF: {ex}")
        except Exception as ex:
            print("psfgen load_wss_opd_by_date failed")
            print(ex)

        log.info(f"starfinding: Calculating grid for psf_fn={psf_fn}")
        # https://github.com/spacetelescope/stpsf/blob/cc16c909b55b2a26e80b074b9ab79ed9a312f14c/stpsf/stpsf_core.py#L640
        # https://github.com/spacetelescope/stpsf/blob/cc16c909b55b2a26e80b074b9ab79ed9a312f14c/stpsf/gridded_library.py#L424
        big_grid = psfgen.psf_grid(num_psfs=npsf, oversample=oversample,
                                   all_detectors=True, fov_pixels=fov_pixels,
                                   outdir=path_prefix,
                                   save=True, outfile=None, overwrite=True)
        # now the PSF should be written
        assert glob.glob(psf_fn.replace(".fits", "*"))
        if isinstance(big_grid, list):
            print(f"PSF FROM PSF_GEN IS A LIST OF GRIDS!!!", flush=True)
            big_grid = big_grid[0]
            # if we really want to get this right, we need to create a new grid of PSF models
            # that is some sort of average of the PSF model grid.
            # There's no way to do it _right_ right without going back to the original data,
            # which is untenable with this approach.  It's a huge project.

    return big_grid
def debug_wrap(function):
    @functools.wraps(function)
    def wrapper(*args, **kwargs):
        print(function.__name__, flush=True)
        return function(*args, **kwargs)
    return wrapper

import os
#os.environ['stpsf_PATH'] = '/orange/adamginsburg/jwst/stpsf-data/'
import stpsf
from stpsf.utils import to_griddedpsfmodel



def get_saturated_stars(fitsdata,path_prefix='/orange/adamginsburg/jwst/w51/psfs/', pad=30, size=None, min_sep_from_edge=5, edge_npix=10000, mask_buffer=1, plot=True, rindsz=3):
    header = fitsdata[0].header
    data = fitsdata['SCI'].data
    data[np.isnan(fitsdata['VAR_POISSON'].data)] = 0
    dq = fitsdata['DQ'].data
    saturated = (dq & dqflags.pixel['SATURATED'])>0 
    sources, nsource = label(saturated)
    print('nsources=', nsource, flush=True)
    sizes = sum_labels(saturated, sources, np.arange(nsource)+1)
    msfe = min_sep_from_edge

    # which sources are edge sources?  Anything w/ more than edge_npix contiguous "saturated" pixels
    # add +1 because 0 is the non-saturated zone that we've excluded
    edge_ids = np.where(sizes > edge_npix)[0] + 1
    edge_mask = np.isin(sources, edge_ids)
    saturated = saturated & (~ndimage.binary_dilation(edge_mask, iterations=msfe))


    big_grid = get_psf(header, path_prefix=path_prefix)
    ww = wcs.WCS(header)

    # We force the centroid to be fixed b/c the fitter doesn't do a great job with this...
    # ....this is not optimal...
    #big_grid.fixed['x_0'] = True
    #big_grid.fixed['y_0'] = True

    # daogroup should be set super high to avoid fitting lots of "stars"... if there are a lot of saturated pixels near each other, they're probably all junk
    daogroup = SourceGrouper(min_separation=25)

    resid = data

    results = []

    lmfitter = LevMarLSQFitter()
    # def levmarverbosewrapper(self, *args, **kwargs):
    #     print("Running lmfitter")
    #     log.info(f"Running lmfitter with args {args} and kwargs {kwargs}")
    #     return self(*args, **kwargs)
    # #lmfitter.__call__ = levmarverbosewrapper
    # lmfitter._run_fitter = levmarverbosewrapper

    if header['INSTRUME'].lower() == 'nircam':
        psfgen = stpsf.NIRCam()
        fwhm, fwhm_pix = get_fwhm(header, instrument_replacement='NIRCam')
    elif header['INSTRUME'].lower() == 'miri':
        psfgen = stpsf.MIRI()
        fwhm, fwhm_pix = get_fwhm(header, instrument_replacement='MIRI')

    
    slices = find_objects(saturated)
    
    # define pad/size/fwhm_pix (choose sensible defaults if not already set)
    size = pad = 81

   
    print(f"Found {nsource} saturated sources to process", flush=True)
    index=0
    for ii in range(nsource):
        if True: # to keep indentation level same
            # get the center of pixels with this label
            
            com = center_of_mass(saturated, labels=sources, index=ii+1)
            # center_of_mass can return (nan, nan) for degenerate labels; guard against that
            if com is None:
                print(f"Source {ii+1}: center_of_mass returned None; skipping", flush=True)
                continue
            yf, xf = com
            if not (np.isfinite(yf) and np.isfinite(xf)):
                print(f"Source {ii+1}: center_of_mass returned NaN or infinite values ({yf}, {xf}); skipping", flush=True)
                continue
            ycen = int(round(yf))
            xcen = int(round(xf))
            print(f"Source {ii+1}: center at (x, y) = ({xcen}, {ycen})")
            y0 = int(max(0, ycen - pad))
            y1 = int(min(data.shape[0], ycen + pad))
            x0 = int(max(0, xcen - pad))
            x1 = int(min(data.shape[1], xcen + pad))
            size_saturated = int(np.sqrt(sum_labels(saturated, labels=sources, index=ii+1))/2)
            area_saturated = sum_labels(saturated, labels=sources, index=ii+1)
            cutout = data[y0:y1, x0:x1]
            init_params = QTable()
            init_params['x'] = [xcen - x0]
            init_params['y'] = [ycen - y0]
            cutout[np.isnan(cutout)] = 0.0
            # if isinstance(grid, list):
            #     print(f"Grid is a list: {grid}")
            #     psf_model = WrappedPSFModel(grid[0])
            #     dao_psf_model = grid[0]
            # else:

            #psf_model = WrappedPSFModel(grid, stampsz=(size,size))


            # get the 5 pixels around the center of mass that are saturated, and get the contrast of those pixels
            


           

           
            psfphot = PSFPhotometry(
                                        localbkg_estimator=LocalBackground(15, 30),
                                        fitter=lmfitter,
                                        psf_model=big_grid,
                                        fit_shape=size,
                                        aperture_radius=15*fwhm_pix)
            low_x  = xcen - x0 - size_saturated
            high_x = xcen - x0 + size_saturated
            low_y  = ycen - y0 - size_saturated
            high_y = ycen - y0 + size_saturated

            # get the underlying model and set bounds there
            model = getattr(psfphot, "psf_model", None)
            if model is None:
                raise RuntimeError("psfphot.psf_model is None — can't set parameter bounds")

            for pname, bounds in (("x_0", (low_x, high_x)), ("y_0", (low_y, high_y))):
                if hasattr(model, pname):
                    param = getattr(model, pname)
                    # try the supported API first
                    try:
                        param.bounds = bounds
                        print(f"Set {pname}.bounds = {bounds}")
                    except (AttributeError, TypeError) as e:
                        # fallback (private attribute) if necessary
                        try:
                            param._bounds = bounds
                            print(f"Set {pname}._bounds = {bounds} (fallback)")
                        except (AttributeError, TypeError) as e:
                            print(f"Could not set bounds for {pname}; parameter object: {param}. Error: {e}")
                else:
                    print(f"Model does not have parameter '{pname}'; param_names={getattr(model,'param_names',None)}")
            # let x_0 be bounds at saturated pixels
            #psfphot.x_0.bounds = (xcen - x0 - size_saturated , xcen - x0 + size_saturated)
            #psfphot.y_0.bounds = (ycen - y0 - size_saturated, ycen - y0 + size_saturated)
            saturated_mask = saturated[y0:y1, x0:x1]
            pixels_around_saturated = ndimage.binary_dilation(saturated_mask, iterations=5)
            contrast = np.nanstd(cutout[pixels_around_saturated]) 
            


            # expand a few pixels of saturated area to be masked
            saturated_mask_expanded = ndimage.binary_dilation(saturated_mask, iterations=mask_buffer)
            mask = np.logical_or(cutout==0, np.isnan(cutout), saturated_mask_expanded)
            try:
                result = psfphot(cutout, init_params=init_params, mask=mask)
            except Exception as ex:
                print(f"PSF photometry failed for source {i+1} at (x,y)=({xcen},{ycen}): {ex}", flush=True)
                continue
            
            result['xcentroid'] = result['x_fit'] + x0
            result['ycentroid'] = result['y_fit'] + y0
            result['skycoord_fit'] = ww.pixel_to_world(result['xcentroid'], result['ycentroid'])

            
            result.pprint(max_width=-1)

            ny = cutout.shape[0]
            nx = cutout.shape[1]
            model_image = np.zeros_like(cutout)
          

           
            



            for x_fit, y_fit, flux in zip(result['x_fit'], result['y_fit'], result['flux_fit']):
                # Make a local grid around the source
                if np.isnan(flux):
                    raise ValueError("Flux is NaN; cannot build PSF model image")
                y, x = np.mgrid[0:ny, 0:nx]
                #psf_eval = big_grid(x, y, flux=flux, x_0=x0, y_0=y0)  # works for analytic PSF
                psf_eval = big_grid(x-x_fit, y-y_fit) * flux  # works for GriddedPSFModel
                # cut psf_eval to the image size
                model_image += psf_eval[0:ny, 0:nx]
            
            threshold_image = np.zeros_like(cutout)

            #count the number of pixels above local background in the model_image
            threshold = np.nanpercentile(cutout, 99)
            threshold_image[model_image>threshold]=1
            num_pixels_above_threshold = np.nansum(threshold_image)
            print(np.nanmax(model_image), flush=True)
            print(f"Number of pixels above threshold ({threshold}): {num_pixels_above_threshold}", flush=True)
           
            if len(result) > 0:
                flux = result['flux_fit'][0]
                fluxerr = result['flux_err'][0]
                snr = result['flux_fit'][0] / result['flux_err'][0]
                qfit = result['qfit'][0]
                cfit = result['cfit'][0]

            
            
            # check whether the pixels with dqflag = saturated are also flagged as HOT, DEAD, and RC
            # this is a sanity check to make sure that the saturated pixels are not being used in the fit
            idx_saturated_in_cutout = (dq[y0:y1, x0:x1] & dqflags.pixel['SATURATED']) > 0
            saturated_dqflags = dq[y0:y1, x0:x1][idx_saturated_in_cutout]
            if np.any((saturated_dqflags & dqflags.pixel['HOT'])!=0):
                print(f"Warning: Some saturated pixels are flagged as HOT; skipping source", flush=True)
                continue
            if np.any((saturated_dqflags & dqflags.pixel['DEAD'])!=0):
                print(f"Warning: Some saturated pixels are flagged as DEAD; skipping source", flush=True)
                continue
            #if np.any((saturated_dqflags & dqflags.pixel['RC'])!=0):
            #    print(f"Warning: Some saturated pixels are flagged as RC; skipping source", flush=True)
            #    continue
            
            if num_pixels_above_threshold< 5:
                print(f"Warning: Only {num_pixels_above_threshold} pixels above threshold; skipping source", flush=True)
                continue
            
            
            # compare FWHM of the model and the size of saturated pixels
            #if area_saturated > num_pixels_above_threshold:
            #    print(f"Warning: Saturated mask area ({area_saturated}) is larger than number of pixels above threshold ({num_pixels_above_threshold}); skipping source", flush=True)
            #    continue
                
            # process the result
            if result is not None and np.isfinite(fluxerr) and snr > 1 and flux > 0:
                print(f"Accepting source {i+1} with flux={flux}, fluxerr={fluxerr}, snr={snr}", flush=True)
                if index == 0:
                    base_tab = result
                else:
                    base_tab = table.vstack([base_tab, result])
                
                index += 1
                if plot:
                    fig = plt.figure(figsize=(12,12))
                    ax1 = fig.add_subplot(2,3,1)
                    ax1.imshow(cutout, origin='lower', cmap='viridis', vmin=0, vmax=np.nanpercentile(cutout, 99))
                    ax1.set_title('Cutout')
                    ax2 = fig.add_subplot(2,3,2)
                    ax2.set_title('Model')
                    ax2.imshow(model_image, origin='lower', cmap='viridis', vmin=0, vmax=np.nanpercentile(cutout, 99))
                    ax3 = fig.add_subplot(2,3,3)
                    resid_image = cutout - model_image
                    ax3.imshow(resid_image, origin='lower', cmap='viridis', vmin=0, vmax=np.nanpercentile(cutout, 99))
                    ax3.set_title('Residual')
                    ax4 = fig.add_subplot(2,3,4)
                    ax4.imshow(mask, origin='lower', cmap='gray')
                    ax4.set_title('Mask')
                    ax5 = fig.add_subplot(2,3,5)
                    ax5.imshow(threshold_image, origin='lower', cmap='gray')
                    ax5.set_title('Thresholded Model Pixels')
                    # print flux, fluxerr, snr, cfit in the title
                    if len(result) > 0:
                        
                    
                        ax1.set_title(f'Cutout\nFlux={flux:.2f}, FluxErr={fluxerr:.2f}, \nSNR={snr:.2f}, qfit={qfit:.2f}, cfit={cfit:.2f}, \ncontrast={contrast:.2f}, num_pixels_above_threshold={num_pixels_above_threshold}')

                    plt.show()
                    plt.close()
            else:
                print(f"Skipping source {ii+1} due to non-finite flux error or low SNR", flush=True)
                print(f"  fluxerr={fluxerr}, snr={snr}", flush=True)

           
            
    # if base_tab is not defined, return None
    # this happens if no saturated stars are found
    if index == 0:
        print('No saturated stars found after processing all sources', flush=True)
        return None
    else:
        return base_tab

def remove_saturated_stars(filename, save_suffix='_unsatstar', **kwargs):
    print(f"Removing saturated stars from {filename}", flush=True)
    fh = fits.open(filename)
    data = fh['SCI'].data

    # there are examples, especially in Faaaaa405, where the variance is NaN but the value
    # is negative
    print(f"Setting NaN variance to 0", flush=True)
    #data[np.isnan(fh['VAR_POISSON'].data)] = 0

    header = fh[0].header
    if 'CRPIX1' not in header:
        header.update(wcs.WCS(fh['SCI'].header).to_header())
    print("Running get_saturated_stars", flush=True)
    satstar_table = get_saturated_stars(fh,plot=True)
    if satstar_table is not None:
        satstar_table.meta.update(header)
        print("Finished get_saturated_stars", flush=True)

        #satstar_table.write(filename.replace(".fits", '_satstar_catalog_newnewnewnew.fits'), overwrite=True)
        print(f"Saved saturated star catalog to {filename.replace('.fits', '_satstar_catalog_newnewnewnew.fits')}", flush=True)
    else:
        print("No saturated stars found", flush=True)
        return
    
    


filts = ['F480M']
for filt in filts:
    if filt in ['F140M', 'F162M', 'F182M', 'F187N', 'F210M', 'F335M', 'F360M', 'F405N', 'F410M', 'F480M']:
        modules = ('nrca', 'nrcb')
    else:
        modules = ('mirim',)
    print(modules)
    for module in modules:
        if filt in ['F140M', 'F162M', 'F182M', 'F187N', 'F210M', 'F335M', 'F360M', 'F405N', 'F410M', 'F480M']:
            globlist = glob.glob(f"/orange/adamginsburg/jwst/w51/{filt}/pipeline/*{module}*_cal.fits")
            print(globlist, module)
        else:
            globlist = glob.glob(f"/orange/adamginsburg/jwst/w51/{filt}/pipeline/*mirimage_cal.fits")
        for i, fn in enumerate(globlist):
            print()
            print(fn)
            if i==6:
                remove_saturated_stars(fn)

        #for module in ('nrca', 'nrcb', 'merged'):
        #    for fn in glob.glob(f"/orange/adamginsburg/jwst/w51/F*/pipeline/*{module}*crf.fits"):
        #        print()
        #        print(fn)
    #        remove_saturated_stars(fn, verbose=True)
# Out:
# STPSF_PATH=/blue/adamginsburg/t.yoo/from_red/stpsf-data
# ('nrca', 'nrcb')
# ['/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00008_nrcalong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00006_nrcalong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00001_nrcalong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00003_nrcalong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00005_nrcalong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00007_nrcalong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00002_nrcalong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00004_nrcalong_cal.fits'] nrca
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00008_nrcalong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00006_nrcalong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00001_nrcalong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00003_nrcalong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00005_nrcalong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00007_nrcalong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00002_nrcalong_cal.fits
# Removing saturated stars from /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00002_nrcalong_cal.fits
# Setting NaN variance to 0
# Running get_saturated_stars
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2025-05-06T16:42:21.768' from MJD-BEG.
# Set DATE-AVG to '2025-05-06T16:44:25.241' from MJD-AVG.
# Set DATE-END to '2025-05-06T16:46:28.714' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -106.567877 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -25.273375 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1611468465.919 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_0_3, A_0_4, A_0_5, A_1_1, A_1_2, A_1_3, A_1_4, A_2_0, A_2_1, A_2_2, A_2_3, A_3_0, A_3_1, A_3_2, A_4_0, A_4_1, A_5_0, B_ORDER, B_0_2, B_0_3, B_0_4, B_0_5, B_1_1, B_1_2, B_1_3, B_1_4, B_2_0, B_2_1, B_2_2, B_2_3, B_3_0, B_3_1, B_3_2, B_4_0, B_4_1, B_5_0, AP_ORDER, AP_0_2, AP_0_3, AP_0_4, AP_0_5, AP_1_1, AP_1_2, AP_1_3, AP_1_4, AP_2_0, AP_2_1, AP_2_2, AP_2_3, AP_3_0, AP_3_1, AP_3_2, AP_4_0, AP_4_1, AP_5_0, BP_ORDER, BP_0_2, BP_0_3, BP_0_4, BP_0_5, BP_1_1, BP_1_2, BP_1_3, BP_1_4, BP_2_0, BP_2_1, BP_2_2, BP_2_3, BP_3_0, BP_3_1, BP_3_2, BP_4_0, BP_4_1, BP_5_0 Use the ``relax`` kwarg to control this. [astropy.wcs.wcs]
# nsources= 19
# from_environment_variable
# path from env var /blue/adamginsburg/t.yoo/from_red/stpsf-data
# path /blue/adamginsburg/t.yoo/from_red/stpsf-data
# This is not a valid WCS!!! CDELT is wrong!! how did this HAPPEN!?!?
# ignoring WCS failure so check that stuff is right...
# INFO: Loading grid from psf_fn=/orange/adamginsburg/jwst/w51/psfs//nircam_nrca5_f480m_fovp512_samp2_npsf16.fits [unknown]
# from_environment_variable
# path from env var /blue/adamginsburg/t.yoo/from_red/stpsf-data
# path /blue/adamginsburg/t.yoo/from_red/stpsf-data
# Found 19 saturated sources to process
# Source 1: center at (x, y) = (1588, 452)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
# WARNING: FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0) [astropy.wcs.wcs]
#  id group_id group_size     local_bkg      x_init y_init     flux_init           x_fit             y_fit            flux_fit             x_err              y_err             flux_err      npixfit        qfit       cfit flags     xcentroid          ycentroid                   skycoord_fit
#                                                                                                                                                                                                                                                                                       deg,deg
# --- -------- ---------- ------------------ ------ ------ ----------------- ----------------- ----------------- ------------------ ------------------- ------------------ ------------------ ------- ----------------- ---- ----- ------------------ ------------------ -------------------------------------
#   1        1          1 15.114834785461426     81     81 78070.06124334034 80.77035406453149 81.61040786308996 394.98256335015753 0.29135589740511836 0.4321836420391578 167.73262041629204    6441 73.42311386161666  nan     1 1587.7703540645316 452.61040786308996 290.92880939673597,14.522877529182564
# 31.368769
# Number of pixels above threshold (42.16359329223633): 0.0
# Accepting source 7 with flux=394.98256335015753, fluxerr=167.73262041629204, snr=2.3548345120338467
# Source 2: center at (x, y) = (1967, 642)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg      x_init y_init     flux_init      x_fit       y_fit            flux_fit     x_err y_err flux_err npixfit        qfit       cfit flags xcentroid     ycentroid                 skycoord_fit
#                                                                                                                                                                                                                           deg,deg
# --- -------- ---------- ------------------ ------ ------ ------------------ ----- ----------------- ----------------- ----- ----- -------- ------- ----------------- ---- ----- --------- ----------------- ------------------------------------
#   1        1          1 471.56402587890625     81     81 2066496.0153281398  80.0 81.38579546208273 790.9757508621399   nan   nan      nan    6466 816.9241875887203  nan     1    1966.0 642.3857954620827 290.9283078230295,14.515513152793124
# 64.22974
# Number of pixels above threshold (878.9351806640625): 0.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 3: center at (x, y) = (1866, 832)
# Set x_0.bounds = (77, 85)
# Set y_0.bounds = (77, 85)
#  id group_id group_size     local_bkg      x_init y_init     flux_init           x_fit             y_fit            flux_fit     x_err y_err flux_err npixfit         qfit        cfit flags     xcentroid         ycentroid                 skycoord_fit
#                                                                                                                                                                                                                                                deg,deg
# --- -------- ---------- ------------------ ------ ------ ----------------- ----------------- ----------------- ----------------- ----- ----- -------- ------- ------------------- ---- ----- ----------------- ----------------- ------------------------------------
#   1        1          1 154.87442016601562     81     81 929350.4674201694 81.38289424541287 80.79678760086944 2585504.501656727   nan   nan      nan    6357 0.27667334216848166  nan     9 1866.382894245413 831.7967876008695 290.9244491191221,14.515819874283268
# 204448.92
# Number of pixels above threshold (1444.7178955078125): 108.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# WARNING: One or more fit(s) may not have converged. Please check the "flags" column in the output table. [photutils.psf.photometry]
# Source 4: center at (x, y) = (686, 831)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg     x_init y_init     flux_init           x_fit             y_fit            flux_fit           x_err              y_err             flux_err      npixfit       qfit       cfit flags    xcentroid         ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                deg,deg
# --- -------- ---------- ----------------- ------ ------ ----------------- ----------------- ----------------- ----------------- ------------------ ------------------ ------------------ ------- ---------------- ---- ----- ---------------- ----------------- -------------------------------------
#   1        1          1 13.94444465637207     81     81 62731.98339470127 81.03049999400902 80.95013184759162 277.8637347670793 0.1659131539513311 0.1573865725858001 56.088582757001994    6401 38.0807118368348  nan     1 686.030499994009 830.9501318475916 290.91615453694186,14.534768058670249
# 23.658731
# Number of pixels above threshold (18.437517166137695): 1.0
# Accepting source 7 with flux=277.8637347670793, fluxerr=56.088582757001994, snr=4.95401597096677
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:11:43 EDT' [astropy.utils.metadata.merge]
# Source 5: center at (x, y) = (1909, 882)
# Set x_0.bounds = (75, 87)
# Set y_0.bounds = (75, 87)
#  id group_id group_size     local_bkg     x_init y_init     flux_init            x_fit             y_fit           flux_fit            x_err               y_err              flux_err     npixfit         qfit        cfit flags     xcentroid          ycentroid                 skycoord_fit
#                                                                                                                                                                                                                                                                                      deg,deg
# --- -------- ---------- ----------------- ------ ------ ------------------ ----------------- ----------------- ---------------- ------------------- -------------------- ----------------- ------- ------------------- ---- ----- ------------------ ----------------- ------------------------------------
#   1        1          1 540.2736206054688     81     81 2741847.2306956872 81.05640194605316 80.81426166677129 8215696.46810601 0.01700942234285605 0.017990884661678593 82269.36322703249    6275 0.18969044620657427  nan     1 1909.0564019460533 881.8142616667712 290.9239156728748,14.514793866769834
# 690202.1
# Number of pixels above threshold (1595.0235595703125): 244.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 6: center at (x, y) = (1047, 975)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg      x_init y_init     flux_init           x_fit             y_fit             flux_fit            x_err              y_err             flux_err     npixfit        qfit        cfit flags     xcentroid          ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                      deg,deg
# --- -------- ---------- ------------------ ------ ------ ----------------- ----------------- ----------------- ------------------- ------------------ ------------------ ----------------- ------- ------------------ ---- ----- ------------------ ----------------- -------------------------------------
#   1        1          1 20.093533515930176     81     81 90979.87925618046 81.24331261413896 80.75785638302578 -25.621675229790785 1.9890052582919853 2.1809180541847493 68.71071809168409    6356 -352.4201570354005  nan     5 1047.2433126141389 974.7578563830258 290.91629989308575,14.527990317196622
# -7.712534e-08
# Number of pixels above threshold (29.133825302124023): 0.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 7: center at (x, y) = (1164, 1100)
# Set x_0.bounds = (79, 83)
# Set y_0.bounds = (79, 83)
#  id group_id group_size    local_bkg     x_init y_init     flux_init          x_fit             y_fit            flux_fit            x_err                y_err             flux_err     npixfit        qfit       cfit flags     xcentroid          ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                   deg,deg
# --- -------- ---------- ---------------- ------ ------ ----------------- ---------------- ----------------- ----------------- -------------------- ------------------- ----------------- ------- ----------------- ---- ----- ------------------ ------------------ ------------------------------------
#   1        1          1 42.1978645324707     81     81 380582.7125438651 81.4614146774393 80.36235805625233 341556.9182173615 0.016043711044305423 0.01414211167533276 6032.916531894115    6375 0.558629735046423  nan     1 1164.4614146774393 1099.3623580562523 290.9150477863692,14.525259191649697
# 25536.021
# Number of pixels above threshold (205.1020965576172): 103.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 8: center at (x, y) = (1557, 1160)
# Set x_0.bounds = (48, 114)
# Set y_0.bounds = (48, 114)
#  id group_id group_size   local_bkg    x_init y_init     flux_init           x_fit             y_fit            flux_fit      x_err y_err flux_err npixfit        qfit        cfit flags     xcentroid         ycentroid                   skycoord_fit
#                                                                                                                                                                                                                                              deg,deg
# --- -------- ---------- -------------- ------ ------ ----------------- ----------------- ----------------- ------------------ ----- ----- -------- ------- ------------------ ---- ----- ----------------- ------------------ -------------------------------------
#   1        1          1 4651.169921875     81     81 8564111.112295631 78.62664834946588 81.52615394967442 11463971.848541528   nan   nan      nan    2812 0.3933885617729422  nan     9 1554.626648349466 1160.5261539496744 290.91677467268653,14.518580593510675
# 860428.9
# Number of pixels above threshold (8256.4423828125): 100.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# WARNING: One or more fit(s) may not have converged. Please check the "flags" column in the output table. [photutils.psf.photometry]
# Source 9: center at (x, y) = (1539, 1123)
# Set x_0.bounds = (79, 83)
# Set y_0.bounds = (79, 83)
#  id group_id group_size   local_bkg   x_init y_init     flux_init           x_fit             y_fit           flux_fit            x_err               y_err             flux_err     npixfit        qfit       cfit flags     xcentroid          ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                               deg,deg
# --- -------- ---------- ------------- ------ ------ ----------------- ----------------- ----------------- ---------------- ------------------- ------------------- ----------------- ------- ----------------- ---- ----- ------------------ ------------------ ------------------------------------
#   1        1          1 2461.71484375     81     81 10773415.95656612 81.38322319698104 81.51458961983406 992305.604474913 0.10990850244625641 0.07169696460654792 91448.83386453768    4948 8.312625118878788  nan     1 1539.3832231969811 1123.5145896198342 290.9172843669568,14.519077698146386
# 73109.23
# Number of pixels above threshold (8210.5): 16.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 10: center at (x, y) = (1620, 1123)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size   local_bkg   x_init y_init     flux_init           x_fit             y_fit            flux_fit           x_err               y_err             flux_err      npixfit        qfit        cfit flags     xcentroid          ycentroid                   skycoord_fit
#                                                                                                                                                                                                                                                                                  deg,deg
# --- -------- ---------- ------------- ------ ------ ----------------- ----------------- ----------------- ----------------- ------------------ ------------------- ------------------ ------- ------------------ ---- ----- ------------------ ------------------ -------------------------------------
#   1        1          1 689.138671875     81     81 5811384.773985904 80.95411537063173 81.01643862573424 344585.7368186454 0.0650384402070173 0.06480324499555355 28094.993618604527    5444 12.764734750194071  nan     1 1619.9541153706318 1123.0164386257343 290.91785982157444,14.517788093446914
# 29409.97
# Number of pixels above threshold (6907.61474609375): 9.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 11: center at (x, y) = (1546, 1135)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size   local_bkg    x_init y_init     flux_init            x_fit             y_fit            flux_fit             x_err              y_err             flux_err      npixfit       qfit       cfit flags     xcentroid          ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                  deg,deg
# --- -------- ---------- -------------- ------ ------ ------------------ ----------------- ----------------- ------------------ ------------------- ------------------ ------------------ ------- ---------------- ---- ----- ------------------ ------------------ ------------------------------------
#   1        1          1 3653.498046875     81     81 10377169.143352268 81.52966837242121 80.95984525545023 297483.45077122806 0.19861643423935965 0.1152016250271379 52841.463340638395    4047 23.7372523614144  nan     1 1546.5296683724212 1134.9598452554503 290.9171438755162,14.518884937132341
# 23619.172
# Number of pixels above threshold (8256.4423828125): 8.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 12: center at (x, y) = (605, 1142)
# Set x_0.bounds = (79, 83)
# Set y_0.bounds = (79, 83)
#  id group_id group_size     local_bkg      x_init y_init     flux_init            x_fit             y_fit            flux_fit             x_err                y_err              flux_err      npixfit         qfit        cfit flags     xcentroid         ycentroid                   skycoord_fit
#                                                                                                                                                                                                                                                                                            deg,deg
# --- -------- ---------- ------------------ ------ ------ ------------------ ----------------- ----------------- ------------------ -------------------- -------------------- ------------------ ------- ------------------- ---- ----- ----------------- ------------------ -------------------------------------
#   1        1          1 16.861722946166992     81     81 176820.79287274776 80.81423726445136 81.02725138950623 388920.35394990974 0.004348587311693119 0.004739166010765381 1069.6897742801816    6391 0.10609146869005773  nan     1 604.8142372644513 1142.0272513895063 290.91039668441204,14.533949281164084
# 32903.125
# Number of pixels above threshold (146.14527893066406): 127.0
# Accepting source 7 with flux=388920.35394990974, fluxerr=1069.6897742801816, snr=363.5823799583604
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:11:48 EDT' [astropy.utils.metadata.merge]
# Source 13: center at (x, y) = (1493, 1160)
# Set x_0.bounds = (79, 83)
# Set y_0.bounds = (79, 83)
#  id group_id group_size    local_bkg     x_init y_init     flux_init           x_fit             y_fit            flux_fit             x_err                y_err             flux_err      npixfit        qfit       cfit flags     xcentroid          ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                      deg,deg
# --- -------- ---------- ---------------- ------ ------ ------------------ ---------------- ----------------- ------------------ -------------------- ------------------- ------------------ ------- ----------------- ---- ----- ------------------ ------------------ ------------------------------------
#   1        1          1 3567.23681640625     81     81 15927559.219180629 80.4800240544417 81.38717081278064 1592424.7416425787 0.058242337487775554 0.07495662079824936 106031.46053896118    5534 6.804759692456929  nan     1 1492.4800240544416 1160.3871708127806 290.9163395245652,14.519578869671651
# 118524.38
# Number of pixels above threshold (8214.3798828125): 20.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 14: center at (x, y) = (1509, 1161)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size    local_bkg     x_init y_init     flux_init           x_fit             y_fit            flux_fit           x_err              y_err            flux_err     npixfit        qfit        cfit flags     xcentroid          ycentroid                   skycoord_fit
#                                                                                                                                                                                                                                                                                  deg,deg
# --- -------- ---------- ---------------- ------ ------ ----------------- ----------------- ----------------- ----------------- ----------------- ------------------- ---------------- ------- ------------------ ---- ----- ------------------ ------------------ -------------------------------------
#   1        1          1 4791.40869140625     81     81 16601613.43278525 80.34489819182753 81.07865137090474 623906.6486146052 0.107014414183443 0.05996536035504386 56920.8970442388    4815 15.123202772863417  nan     1 1508.3448981918275 1161.0786513709047 290.91643967436335,14.519319553458175
# 50554.63
# Number of pixels above threshold (8246.103515625): 16.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 15: center at (x, y) = (1629, 1165)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg     x_init y_init     flux_init           x_fit             y_fit            flux_fit           x_err               y_err             flux_err     npixfit        qfit        cfit flags     xcentroid          ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                    deg,deg
# --- -------- ---------- ----------------- ------ ------ ----------------- ----------------- ----------------- ----------------- ------------------ ------------------- ----------------- ------- ------------------ ---- ----- ------------------ ------------------ ------------------------------------
#   1        1          1 796.5187683105469     81     81 5186535.043355884 81.24207088608219 81.36077867042573 308800.8418463061 0.1049279843882985 0.10584154421808184 40843.37329976959    5811 12.516189506215566  nan     1 1629.2420708860823 1165.3607786704258 290.9172193089731,14.517350185491917
# 24571.096
# Number of pixels above threshold (6393.68701171875): 13.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 16: center at (x, y) = (1191, 1170)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg      x_init y_init     flux_init            x_fit             y_fit            flux_fit            x_err             y_err           flux_err     npixfit        qfit       cfit flags     xcentroid          ycentroid                   skycoord_fit
#                                                                                                                                                                                                                                                                                   deg,deg
# --- -------- ---------- ------------------ ------ ------ ------------------ ----------------- ----------------- ------------------ ----------------- ----------------- ---------------- ------- ----------------- ---- ----- ------------------ ------------------ -------------------------------------
#   1        1          1 23.768733024597168     81     81 127559.45216957068 80.44945843337946 81.29279219256672 -81.04522835316408 5.643048381284611 4.893706595947021 498.480160964363    6433 -544.154509745223  nan     5 1190.4494584333795 1170.2927921925668 290.91404826922087,14.524358265823755
# -2.4182782e-07
# Number of pixels above threshold (212.81239318847656): 0.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 17: center at (x, y) = (1806, 1548)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg      x_init y_init     flux_init            x_fit             y_fit            flux_fit              x_err                 y_err              flux_err      npixfit         qfit        cfit flags     xcentroid          ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                              deg,deg
# --- -------- ---------- ------------------ ------ ------ ------------------ ----------------- ----------------- ------------------ --------------------- --------------------- ------------------ ------- ------------------- ---- ----- ------------------ ------------------ ------------------------------------
#   1        1          1 17.690242767333984     81     81 145270.14792198298 80.77404579878015 81.01095977910062 171153.50163647448 0.0012258901656759394 0.0011624999096283783 256.68753928291613    6461 0.20644186377735874  nan     1 1805.7740457987802 1548.0109597791006 290.91208319589884,14.51190686169856
# 14406.324
# Number of pixels above threshold (56.9716911315918): 156.0
# Accepting source 7 with flux=171153.50163647448, fluxerr=256.68753928291613, snr=666.7776009486473
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:11:50 EDT' [astropy.utils.metadata.merge]
# Source 18: center at (x, y) = (1283, 1616)
# Set x_0.bounds = (78, 84)
# Set y_0.bounds = (78, 84)
#  id group_id group_size     local_bkg      x_init y_init     flux_init            x_fit             y_fit            flux_fit            x_err                y_err              flux_err      npixfit         qfit        cfit flags     xcentroid         ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                          deg,deg
# --- -------- ---------- ------------------ ------ ------ ------------------ ----------------- ----------------- ----------------- -------------------- -------------------- ------------------ ------- ------------------- ---- ----- ----------------- ------------------ ------------------------------------
#   1        1          1 16.417407035827637     81     81 253788.56984013144 81.13102236524412 80.97938998545052 978622.2198121358 0.004090473582827524 0.004099554660892681 2307.9072235224908    6402 0.07665786077240853  nan     1 1283.131022365244 1615.9793899854506 290.9072709516042,14.519830432587225
# 82756.55
# Number of pixels above threshold (156.3660430908203): 287.0
# Accepting source 7 with flux=978622.2198121358, fluxerr=2307.9072235224908, snr=424.03013857658175
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:11:51 EDT' [astropy.utils.metadata.merge]
# Source 19: center at (x, y) = (1806, 1942)
# Set x_0.bounds = (79, 83)
# Set y_0.bounds = (79, 83)
#  id group_id group_size     local_bkg      x_init y_init     flux_init            x_fit            y_fit            flux_fit            x_err               y_err             flux_err      npixfit         qfit        cfit flags     xcentroid          ycentroid                   skycoord_fit
#                                                                                                                                                                                                                                                                                         deg,deg
# --- -------- ---------- ------------------ ------ ------ ------------------ ----------------- ---------------- ----------------- -------------------- ------------------ ------------------ ------- ------------------- ---- ----- ------------------ ------------------ -------------------------------------
#   1        1          1 12.268632888793945     81     81 160917.58428762428 80.63512787554171 80.6127365619718 491644.1244959259 0.008811272220507196 0.0092894558409919 2393.9622809009584    6424 0.11684084543675265  nan     1 1805.6351278755417 1941.6127365619718 290.90552108353006,14.509223867902454
# 38020.383
# Number of pixels above threshold (79.11441040039062): 275.0
# Accepting source 7 with flux=491644.1244959259, fluxerr=2393.9622809009584, snr=205.36836708676026
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:11:52 EDT' [astropy.utils.metadata.merge]
# Finished get_saturated_stars
# Saved saturated star catalog to /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00002_nrcalong_cal_satstar_catalog_newnewnewnew.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00004_nrcalong_cal.fits
# ['/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00001_nrcblong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00008_nrcblong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00005_nrcblong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00007_nrcblong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00002_nrcblong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00003_nrcblong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00004_nrcblong_cal.fits', '/orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00006_nrcblong_cal.fits'] nrcb
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00001_nrcblong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00008_nrcblong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00005_nrcblong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00007_nrcblong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00002_nrcblong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00003_nrcblong_cal.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00004_nrcblong_cal.fits
# Removing saturated stars from /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00004_nrcblong_cal.fits
# Setting NaN variance to 0
# Running get_saturated_stars
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2025-05-06T16:52:44.488' from MJD-BEG.
# Set DATE-AVG to '2025-05-06T16:54:47.961' from MJD-AVG.
# Set DATE-END to '2025-05-06T16:56:51.434' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to  -106.562883 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -25.276708 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1611528526.261 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_0_3, A_0_4, A_0_5, A_1_1, A_1_2, A_1_3, A_1_4, A_2_0, A_2_1, A_2_2, A_2_3, A_3_0, A_3_1, A_3_2, A_4_0, A_4_1, A_5_0, B_ORDER, B_0_2, B_0_3, B_0_4, B_0_5, B_1_1, B_1_2, B_1_3, B_1_4, B_2_0, B_2_1, B_2_2, B_2_3, B_3_0, B_3_1, B_3_2, B_4_0, B_4_1, B_5_0, AP_ORDER, AP_0_2, AP_0_3, AP_0_4, AP_0_5, AP_1_1, AP_1_2, AP_1_3, AP_1_4, AP_2_0, AP_2_1, AP_2_2, AP_2_3, AP_3_0, AP_3_1, AP_3_2, AP_4_0, AP_4_1, AP_5_0, BP_ORDER, BP_0_2, BP_0_3, BP_0_4, BP_0_5, BP_1_1, BP_1_2, BP_1_3, BP_1_4, BP_2_0, BP_2_1, BP_2_2, BP_2_3, BP_3_0, BP_3_1, BP_3_2, BP_4_0, BP_4_1, BP_5_0 Use the ``relax`` kwarg to control this. [astropy.wcs.wcs]
# nsources= 16
# from_environment_variable
# path from env var /blue/adamginsburg/t.yoo/from_red/stpsf-data
# path /blue/adamginsburg/t.yoo/from_red/stpsf-data
# This is not a valid WCS!!! CDELT is wrong!! how did this HAPPEN!?!?
# ignoring WCS failure so check that stuff is right...
# INFO: Loading grid from psf_fn=/orange/adamginsburg/jwst/w51/psfs//nircam_nrcb5_f480m_fovp512_samp2_npsf16.fits [unknown]
# from_environment_variable
# path from env var /blue/adamginsburg/t.yoo/from_red/stpsf-data
# path /blue/adamginsburg/t.yoo/from_red/stpsf-data
# Found 16 saturated sources to process
# Source 1: center at (x, y) = (2040, 6)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (5, 7)
# WARNING: FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0) [astropy.wcs.wcs]
#  id group_id group_size     local_bkg     x_init y_init     flux_init          x_fit       y_fit      flux_fit     x_err y_err flux_err npixfit        qfit       cfit flags     xcentroid      ycentroid             skycoord_fit
#                                                                                                                                                                                                                         deg,deg
# --- -------- ---------- ----------------- ------ ------ ----------------- ---------------- ----- ----------------- ----- ----- -------- ------- ----------------- ---- ----- ------------------ --------- ------------------------------------
#   1        1          1 5.228219032287598     81      6 6665.734688633732 80.7862139216184   5.0 976.3709365478636   nan   nan      nan    1725 0.490855388070596  nan     1 2039.7862139216184       5.0 290.9650010695375,14.476133781243652
# 82.58707
# Number of pixels above threshold (8.388543128967285): 18.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 2: center at (x, y) = (294, 45)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (44, 46)
#  id group_id group_size     local_bkg      x_init y_init     flux_init          x_fit             y_fit            flux_fit             x_err               y_err             flux_err     npixfit        qfit       cfit flags     xcentroid         ycentroid                 skycoord_fit
#                                                                                                                                                                                                                                                                                   deg,deg
# --- -------- ---------- ------------------ ------ ------ ----------------- ---------------- ----------------- ------------------ ------------------- ------------------- ----------------- ------- ----------------- ---- ----- ----------------- ----------------- ------------------------------------
#   1        1          1 20.481693267822266     81     45 95601.19729645536 80.9964008826661 45.03225403640818 195.61137153069026 0.18992945536078082 0.18944848303685785 47.24086837098625    6458 46.04672486766715  nan     1 293.9964008826661 45.03225403640818 290.95215988470375,14.50397660322908
# 16.794855
# Number of pixels above threshold (34.8371467590332): 0.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 3: center at (x, y) = (49, 78)
# Set x_0.bounds = (48, 50)
# Set y_0.bounds = (77, 79)
#  id group_id group_size     local_bkg      x_init y_init     flux_init            x_fit              y_fit            flux_fit             x_err                 y_err              flux_err      npixfit        qfit        cfit flags     xcentroid          ycentroid                skycoord_fit
#                                                                                                                                                                                                                                                                                           deg,deg
# --- -------- ---------- ------------------ ------ ------ ------------------ ------------------ ----------------- ------------------ -------------------- --------------------- ------------------ ------- ------------------ ---- ----- ------------------ ----------------- ----------------------------------
#   1        1          1 15.993001461029053     49     78 115688.05394879122 49.079479763714545 77.47078016046387 140458.23408880242 0.001130137652606469 0.0018520199620970872 243.01725357236992    6414 0.1459698256095026  nan     1 49.079479763714545 77.47078016046387 290.949910078002,14.50770007899325
# 11132.411
# Number of pixels above threshold (47.07560348510742): 146.0
# Accepting source 7 with flux=140458.23408880242, fluxerr=243.01725357236992, snr=577.9763865489259
# Source 4: center at (x, y) = (424, 266)
# Set x_0.bounds = (78, 84)
# Set y_0.bounds = (78, 84)
#  id group_id group_size     local_bkg      x_init y_init     flux_init           x_fit            y_fit            flux_fit             x_err                y_err             flux_err     npixfit         qfit        cfit flags     xcentroid         ycentroid                 skycoord_fit
#                                                                                                                                                                                                                                                                                      deg,deg
# --- -------- ---------- ------------------ ------ ------ ----------------- ----------------- ---------------- ------------------ -------------------- -------------------- ---------------- ------- ------------------- ---- ----- ----------------- ----------------- ------------------------------------
#   1        1          1 31.471965789794922     81     81 213339.9429484818 81.15943944594409 80.8561556310002 371769.17814912146 0.002953980226941742 0.003073169245526027 614.092239707051    6421 0.11020978089362193  nan     1 424.1594394459441 265.8561556310002 290.9493788756582,14.500377610953613
# 31345.578
# Number of pixels above threshold (93.24104309082031): 201.0
# Accepting source 7 with flux=371769.17814912146, fluxerr=614.092239707051, snr=605.3963136327397
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:11:56 EDT' [astropy.utils.metadata.merge]
# Source 5: center at (x, y) = (2007, 315)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg     x_init y_init     flux_init           x_fit            y_fit            flux_fit            x_err                y_err              flux_err     npixfit        qfit       cfit flags     xcentroid          ycentroid                 skycoord_fit
#                                                                                                                                                                                                                                                                                    deg,deg
# --- -------- ---------- ----------------- ------ ------ ------------------ ---------------- ---------------- ----------------- -------------------- -------------------- ----------------- ------- ----------------- ---- ----- ------------------ ----------------- ------------------------------------
#   1        1          1 8.398120403289795     81     81 145993.22926402552 80.6873830374739 81.0019742737767 95211.40526006377 0.025582265263478406 0.023329809833480843 2981.941024192274    6001 0.892275725984669  nan     1 2006.6873830374739 315.0019742737767 290.9595924856613,14.474557386206722
# 7906.0996
# Number of pixels above threshold (98.0054931640625): 88.0
# Accepting source 7 with flux=95211.40526006377, fluxerr=2981.941024192274, snr=31.92933880570422
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:11:57 EDT' [astropy.utils.metadata.merge]
# Source 6: center at (x, y) = (915, 403)
# Set x_0.bounds = (78, 84)
# Set y_0.bounds = (78, 84)
#  id group_id group_size     local_bkg      x_init y_init     flux_init            x_fit             y_fit            flux_fit            x_err                y_err              flux_err      npixfit         qfit        cfit flags     xcentroid         ycentroid                 skycoord_fit
#                                                                                                                                                                                                                                                                                         deg,deg
# --- -------- ---------- ------------------ ------ ------ ------------------ ----------------- ----------------- ----------------- -------------------- -------------------- ------------------ ------- ------------------- ---- ----- ----------------- ----------------- ------------------------------------
#   1        1          1 14.729045867919922     81     81 151259.75009673723 81.22141768459464 80.53398658897319 560751.2850222078 0.006875075678881671 0.007012352307907779 2327.4893772220166    6414 0.10805443449855989  nan     1 915.2214176845946 402.5339865889732 290.95052016964536,14.49153922377877
# 43592.21
# Number of pixels above threshold (79.32806396484375): 300.0
# Accepting source 7 with flux=560751.2850222078, fluxerr=2327.4893772220166, snr=240.9253896107979
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:11:58 EDT' [astropy.utils.metadata.merge]
# Source 7: center at (x, y) = (1336, 459)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg      x_init y_init     flux_init           x_fit             y_fit            flux_fit            x_err              y_err             flux_err     npixfit        qfit       cfit flags     xcentroid          ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                    deg,deg
# --- -------- ---------- ------------------ ------ ------ ----------------- ----------------- ----------------- ------------------ ------------------ ------------------ ----------------- ------- ----------------- ---- ----- ------------------ ----------------- -------------------------------------
#   1        1          1 13.504302978515625     81     81 69305.67753023907 81.17170194472254 80.94778629656221 349.99162844280744 0.9154451690301868 1.0009817680390494 430.2846600072048    6462 50.06015854649378  nan     1 1336.1717019447226 458.9477862965622 290.95251314014837,14.484376160950275
# 29.662169
# Number of pixels above threshold (19.967166900634766): 3.0
# Skipping source 7 due to non-finite flux error or low SNR
#   fluxerr=430.2846600072048, snr=0.8133955517655383
# Source 8: center at (x, y) = (1969, 506)
# Set x_0.bounds = (77, 85)
# Set y_0.bounds = (77, 85)
#  id group_id group_size    local_bkg     x_init y_init     flux_init            x_fit             y_fit            flux_fit             x_err                y_err             flux_err     npixfit         qfit        cfit flags     xcentroid          ycentroid                   skycoord_fit
#                                                                                                                                                                                                                                                                                         deg,deg
# --- -------- ---------- ---------------- ------ ------ ------------------ ----------------- ----------------- ------------------ -------------------- -------------------- ---------------- ------- ------------------- ---- ----- ------------------ ------------------ -------------------------------------
#   1        1          1 33.2536506652832     81     81 269902.37077008927 81.09175890897592 81.28464116482073 1098133.3430623473 0.007326894997334794 0.008562146618642163 7651.08533571681    6357 0.15362556058449015  nan     1 1969.0917589089759 506.28464116482075 290.95613549913344,14.473861184254304
# 91409.26
# Number of pixels above threshold (171.23916625976562): 290.0
# Accepting source 7 with flux=1098133.3430623473, fluxerr=7651.08533571681, snr=143.5264795618001
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:11:59 EDT' [astropy.utils.metadata.merge]
# Source 9: center at (x, y) = (632, 513)
# Set x_0.bounds = (79, 83)
# Set y_0.bounds = (79, 83)
#  id group_id group_size     local_bkg     x_init y_init     flux_init           x_fit             y_fit            flux_fit             x_err                 y_err              flux_err     npixfit        qfit        cfit flags     xcentroid         ycentroid                 skycoord_fit
#                                                                                                                                                                                                                                                                                       deg,deg
# --- -------- ---------- ----------------- ------ ------ ----------------- ----------------- ----------------- ------------------ -------------------- --------------------- ----------------- ------- ------------------ ---- ----- ----------------- ----------------- ------------------------------------
#   1        1          1 35.58617401123047     81     81 195776.4115766621 80.96483724983689 80.64582617723329 160759.15735481336 0.008548104743468357 0.0058517846169113645 804.9800578048292    6448 0.4904631456732701  nan     1 631.9648372498369 512.6458261772333 290.9467056765286,14.495351498837131
# 13165.622
# Number of pixels above threshold (81.15167999267578): 103.0
# Accepting source 7 with flux=160759.15735481336, fluxerr=804.9800578048292, snr=199.70576388339558
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:12:00 EDT' [astropy.utils.metadata.merge]
# Source 10: center at (x, y) = (1753, 1139)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg     x_init y_init     flux_init            x_fit             y_fit             flux_fit            x_err              y_err            flux_err      npixfit         qfit        cfit flags     xcentroid          ycentroid                 skycoord_fit
#                                                                                                                                                                                                                                                                                      deg,deg
# --- -------- ---------- ----------------- ------ ------ ------------------ ----------------- ----------------- ------------------- ------------------ ----------------- ------------------ ------- ------------------- ---- ----- ------------------ ----------------- ------------------------------------
#   1        1          1 4.998913764953613     81     81 23064.761027960936 81.37666202173662 80.93100742523517 -28.108615248143725 0.9794245551637618 0.833250744592275 32.495907832955204    6448 -115.21616032332052  nan     5 1753.3766620217366 1138.931007425235 290.9440649190505,14.473029679333091
# -5.6780763e-08
# Number of pixels above threshold (6.840960502624512): 0.0
# Skipping source 10 due to non-finite flux error or low SNR
#   fluxerr=32.495907832955204, snr=-0.8649893824365732
# Source 11: center at (x, y) = (1978, 1404)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg     x_init y_init     flux_init     x_fit      y_fit           flux_fit      x_err y_err flux_err npixfit        qfit       cfit flags xcentroid     ycentroid                  skycoord_fit
#                                                                                                                                                                                                                         deg,deg
# --- -------- ---------- ----------------- ------ ------ ----------------- ----- --------------- ------------------ ----- ----- -------- ------- ----------------- ---- ----- --------- ----------------- -------------------------------------
#   1        1          1 8.939065933227539     81     81 41799.07114134301  82.0 80.057854751981 -12.78681409545393   nan   nan      nan    6405 -647.998572767385  nan     5    1979.0 1403.057854751981 290.94122686096614,14.467598567197363
# -2.6746324e-08
# Number of pixels above threshold (13.752573013305664): 0.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 12: center at (x, y) = (1253, 1511)
# Set x_0.bounds = (79, 83)
# Set y_0.bounds = (79, 83)
#  id group_id group_size     local_bkg     x_init y_init     flux_init            x_fit             y_fit            flux_fit             x_err                y_err              flux_err     npixfit         qfit        cfit flags     xcentroid         ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                         deg,deg
# --- -------- ---------- ----------------- ------ ------ ------------------ ----------------- ----------------- ------------------ -------------------- -------------------- ----------------- ------- ------------------- ---- ----- ----------------- ------------------ ------------------------------------
#   1        1          1 13.95725154876709     81     81 105457.86583170472 81.51106155465595 80.71210511415691 176087.56705298598 0.003727411752755832 0.005089394407879337 713.2836229667926    6438 0.16173872213313778  nan     1 1253.511061554656 1510.7121051141569 290.9343696853612,14.478549096780108
# 13436.951
# Number of pixels above threshold (49.46317672729492): 180.0
# Accepting source 7 with flux=176087.56705298598, fluxerr=713.2836229667926, snr=246.8689331749649
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:12:03 EDT' [astropy.utils.metadata.merge]
# Source 13: center at (x, y) = (1132, 1863)
# Set x_0.bounds = (79, 83)
# Set y_0.bounds = (79, 83)
#  id group_id group_size     local_bkg      x_init y_init     flux_init          x_fit            y_fit            flux_fit            x_err               y_err              flux_err      npixfit         qfit        cfit flags    xcentroid         ycentroid                 skycoord_fit
#                                                                                                                                                                                                                                                                                    deg,deg
# --- -------- ---------- ------------------ ------ ------ ------------------ -------------- ----------------- ----------------- ------------------- -------------------- ------------------ ------- ------------------- ---- ----- ---------------- ----------------- -----------------------------------
#   1        1          1 14.699856758117676     81     81 126986.13127132546 81.66607968302 81.46547912846694 271163.0315839686 0.00821907536982403 0.008861980017151487 1259.5440044463785    6421 0.11704925924027437  nan     1 1132.66607968302 1863.465479128467 290.927635271752,14.478094030578122
# 20817.613
# Number of pixels above threshold (59.43000030517578): 221.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 14: center at (x, y) = (4, 1869)
# Set x_0.bounds = (3, 5)
# Set y_0.bounds = (80, 82)
#  id group_id group_size     local_bkg      x_init y_init     flux_init     x_fit y_fit      flux_fit      x_err y_err flux_err npixfit         qfit        cfit flags xcentroid ycentroid             skycoord_fit
#                                                                                                                                                                                                         deg,deg
# --- -------- ---------- ------------------ ------ ------ ----------------- ----- ----- ------------------ ----- ----- -------- ------- ------------------- ---- ----- --------- --------- ------------------------------------
#   1        1          1 31.866580963134766      4     81 70808.25515280777   5.0  82.0 -8886.751693652825   nan   nan      nan    3072 -1.5600326194696608  nan     5       5.0    1870.0 290.9196607312475,14.496208991336722
# -3.8153747e-05
# Number of pixels above threshold (53.748939514160156): 0.0
# Warning: Some saturated pixels are flagged as HOT; skipping source
# Source 15: center at (x, y) = (312, 1922)
# Set x_0.bounds = (79, 83)
# Set y_0.bounds = (79, 83)
#  id group_id group_size     local_bkg      x_init y_init     flux_init           x_fit             y_fit            flux_fit             x_err                 y_err              flux_err      npixfit        qfit       cfit flags     xcentroid         ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                         deg,deg
# --- -------- ---------- ------------------ ------ ------ ----------------- ----------------- ----------------- ------------------ -------------------- --------------------- ------------------ ------- ----------------- ---- ----- ----------------- ----------------- -------------------------------------
#   1        1          1 130.29168701171875     81     81 599441.5629810356 81.36562574023928 80.64894622968285 153508.78104575325 0.007289004186563716 0.0069700114659722685 1328.0345935211274    6481 1.015579539971329  nan     1 312.3656257402393 1921.648946229683 290.92094204954617,14.490907735753927
# 11961.51
# Number of pixels above threshold (171.75802612304688): 89.0
# Accepting source 7 with flux=153508.78104575325, fluxerr=1328.0345935211274, snr=115.5909505630744
# WARNING: MergeConflictWarning: Cannot merge meta key 'date' types <class 'str'> and <class 'str'>, choosing date='2026-03-21 17:12:05 EDT' [astropy.utils.metadata.merge]
# Source 16: center at (x, y) = (185, 1995)
# Set x_0.bounds = (80, 82)
# Set y_0.bounds = (80, 82)
#  id group_id group_size    local_bkg    x_init y_init     flux_init           x_fit             y_fit            flux_fit              x_err                y_err              flux_err     npixfit        qfit       cfit flags     xcentroid          ycentroid                  skycoord_fit
#                                                                                                                                                                                                                                                                                      deg,deg
# --- -------- ---------- --------------- ------ ------ ----------------- ----------------- ----------------- ------------------ --------------------- -------------------- ----------------- ------- ----------------- ---- ----- ------------------ ------------------ ------------------------------------
#   1        1          1 66.621826171875     81     81 358636.9462218008 80.88580370689058 81.17907163602659 130975.28083229344 0.0025306057549906507 0.002598668907882403 428.8477440402197    6452 0.733262822231181  nan     1 184.88580370689058 1995.1790716360265 290.9188246967436,14.492460037242848
# 11092.044
# Number of pixels above threshold (111.37523651123047): 94.0
# Accepting source 7 with flux=130975.28083229344, fluxerr=428.8477440402197, snr=305.41207841823194
# Finished get_saturated_stars
# Saved saturated star catalog to /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00004_nrcblong_cal_satstar_catalog_newnewnewnew.fits
#
# /orange/adamginsburg/jwst/w51/F480M/pipeline/jw06151001001_03109_00006_nrcblong_cal.fits
