# %%
import glob
import time
import numpy
import crowdsource
import regions
import numpy as np
from functools import cache
from astropy.convolution import convolve, Gaussian2DKernel
from astropy.table import Table
from astropy.coordinates import SkyCoord
from astropy.visualization import simple_norm
from astropy.modeling.fitting import LevMarLSQFitter
from astropy import wcs
from astropy import table
from astropy import stats
from astropy import units as u
from astropy.nddata import NDData
from astropy.io import fits
from scipy import ndimage
import requests
import requests.exceptions
import urllib3
import urllib3.exceptions
from photutils.detection import DAOStarFinder, IRAFStarFinder
from photutils.psf import IntegratedGaussianPRF, extract_stars, EPSFStars, EPSFModel
try:
    # version >=1.7.0, doesn't work: the PSF is broken (https://github.com/astropy/photutils/issues/1580?)
    from photutils.psf import PSFPhotometry, IterativePSFPhotometry, SourceGrouper
except:
    # version 1.6.0, which works
    from photutils.psf import BasicPSFPhotometry as PSFPhotometry, IterativelySubtractedPSFPhotometry as IterativePSFPhotometry, DAOGroup as SourceGrouper
try:
    from photutils.background import MMMBackground, MADStdBackgroundRMS, MedianBackground, Background2D, LocalBackground
except:
    from photutils.background import MMMBackground, MADStdBackgroundRMS, MedianBackground, Background2D
    from photutils.background import MMMBackground as LocalBackground

from photutils.psf import EPSFBuilder
from photutils.psf import extract_stars

import warnings
from astropy.utils.exceptions import AstropyWarning, AstropyDeprecationWarning
warnings.simplefilter('ignore', category=AstropyWarning)
warnings.simplefilter('ignore', category=AstropyDeprecationWarning)

from crowdsource import crowdsource_base
from crowdsource.crowdsource_base import fit_im, psfmod

from astroquery.svo_fps import SvoFps
from astropy.table import Table, vstack

import pylab as pl
pl.rcParams['figure.facecolor'] = 'w'
pl.rcParams['image.origin'] = 'lower'

import os
print("Importing webbpsf", flush=True)
import stpsf as webbpsf
print(f"Webbpsf version: {webbpsf.__version__}")
from webbpsf.utils import to_griddedpsfmodel
import datetime
import subprocess
from astropy.coordinates import SkyCoord, FK5
from regions import PixCoord
print("Done with imports", flush=True)
# step i )  load the catalog and do the quality assessment
# for the quality assessment, some tests are required to see the effect of masking
# load the catalog obtained from each exposure file



def get_filenames(basepath, filtername, proposal_id, field, each_suffix, module, pupil='clear', visitid='001'):

    # jw01182004002_02101_00012_nrcalong_destreak_o004_crf.fits
    # jw02221001001_07101_00012_nrcalong_destreak_o001_crf.fits
    # jw02221001001_05101_00022_nrcb3_destreak_o001_crf.fits
    glstr = f'{basepath}/{filtername}/pipeline/jw0{proposal_id}*{module}*_{each_suffix}.fits'
    
  
    fglob = glob.glob(glstr)
    for st in fglob:
        
        if 'align' in st or 'uncal' in st:
            print(f"Removing {st} from glob string because it is an alignment file")
            fglob.remove(st)
    if len(fglob) == 0:
        raise ValueError(f"No matches found to {glstr}")
    else:
        return fglob
filternames = ['F140M', 'F162M', 'F182M', 'F187N', 'F210M', 'F335M', 'F360M', 'F405N', 'F410M', 'F480M', 'F560W', 'F770W', 'F1000W', 'F1280W', 'F2100W']

#filternames = [ 'F162M']

#filternames = ['F335M', 'F360M', 'F405N', 'F410M', 'F480M']
#filternames = ['F162M']
#filternames=['F140M', 'F480M', 'F560W']
proposal_id = '6151'
target = 'w51'
#index = -1

nvisits = {'2221': {'brick': 1, 'cloudc': 2},
               '1182': {'brick': 2},
               '6151': {'w51': 1, 'w51_miri': 2}
               }
field_to_reg_mapping = {'2221': {'001': 'brick', '002': 'cloudc'},
                        '1182': {'004': 'brick'},
                        '6151': {'001': 'w51', '002':'w51_miri'}}[proposal_id]
reg_to_field_mapping = {v:k for k,v in field_to_reg_mapping.items()}
field = reg_to_field_mapping[target]

basepath = f'/orange/adamginsburg/jwst/{field_to_reg_mapping[field]}'


nircam_filters = ['F140M', 'F162M', 'F182M', 'F187N', 'F200W', 'F210M', 'F277W', 'F300M', 'F335M', 'F356W', 'F360M', 'F405N', 'F410M', 'F430M', 'F444W', 'F460M', 'F480M']
miri_filters = ['F560W', 'F770W', 'F1000W', 'F1130W', 'F1280W', 'F1500W', 'F1800W', 'F2100W', 'F2550W']



for filtername in filternames:
    if filtername in nircam_filters:
        modules = ['nrca', 'nrcb']
        instrument = 'NIRCam'
        target = 'w51'
    elif filtername in miri_filters:
        modules = ['mirimage']
        instrument = 'MIRI'
        target = 'w51_miri'
    else:
        raise ValueError(f"Filter {filtername} not recognized as NIRCam or MIRI")
    
    for module in modules:
        
        for visitid in range(1, nvisits[proposal_id][target] + 1):
            visitid = f'{visitid:03d}'
            
            filenames = get_filenames(basepath, filtername, proposal_id,
                                        field, visitid=visitid,
                                        each_suffix='cal',
                                        module=module, pupil='clear')
            for i, filename in enumerate(filenames):
                if True:
                    exposurenumber = int(filename.split("_")[2])
                    exposure_id = filename.split("_")[2]
                    visit_id = filename.split("_")[0][-3:]
                    vgroup_id = filename.split("_")[1]
                    exposure_ = f'_exp{exposurenumber:05d}'
                    visitid_ = f'_visit{int(visitid):03d}' if visitid is not None else ''
                    if instrument == 'NIRCam':
                        vgroupid_ = f'_vgroup{int(vgroup_id)}' if vgroup_id is not None else ''
                    elif instrument == 'MIRI':
                        vgroupid_ = f'_vgroup{vgroup_id}' if vgroup_id is not None else ''
                    detector = filename.split("_")[-2]
                    print(detector, flush=True)
                    #f360m_nrcb_visit001_vgroup3105_exp00008_daophot_basic.fits
                    #/orange/adamginsburg/jwst/w51/F360M/f360m_nrcalong_visit001_vgroup3105_exp00005_daophot_basic.fits
                
                    wav = int(filtername[1:4])
                    if wav < 250:
                        catalogfile = f"{basepath}/{filtername}/{filtername.lower()}_{detector}{visitid_}{vgroupid_}{exposure_}_daophot_basic.fits"
                    else:
                        catalogfile = f"{basepath}/{filtername}/{filtername.lower()}_{module}{visitid_}{vgroupid_}{exposure_}_daophot_basic.fits"
                    print(catalogfile)
                    #f560w_mirimage_visit002_vgroup02101_exp00001_daophot_iterative.fits
                    cat = Table.read(catalogfile)
                    roundness1 = cat['roundness1']
                    roundness2 = cat['roundness2']
                    sharpness = cat['sharpness']
                    flux = cat['flux_fit']
                    fluxerr = cat['flux_err']
                    snr = flux/fluxerr
                    qfit = cat['qfit']
                    cfit = cat['cfit']
                    #skycoord = cat['skycoord']
                    #n_match_good = cat['nmatch_good']
                    #std_ra = cat['std_ra']
                    #std_dec = cat['std_dec']

                    if instrument == 'NIRCam':              
                        good_sources = ((roundness1 < 0.8) & (roundness1 > -0.9) & (roundness2 < 0.6) & (roundness2 > -0.6) & (sharpness < 1.2) & (sharpness>0.25) 
                        & (snr > 3) & (qfit < 0.33) & (cfit < 0.2) & (cfit > -0.2) & ~((snr < 20) & (flux > 50)))
                        
                    elif instrument == 'MIRI':
                        good_sources = ((roundness1 < 0.7) & (roundness1 > -0.7) & (roundness2 < 0.5) & (roundness2 > -0.5) & (sharpness < 1.1) & (sharpness>0.4) 
                        & (snr > 3) & (qfit < 0.6) & (cfit < 0.06) & (cfit > -0.06))
                    
                    refined_cat = cat[good_sources]
                    print(f"Filter {filtername} Module {module} Visit {visitid} Exposure {exposure_id}: {len(cat)} sources, {len(refined_cat)} after quality cuts", flush=True)
                    outcatfile = catalogfile.replace('_daophot_basic.fits', '_daophot_refined.fits')
                    refined_cat.write(outcatfile, overwrite=True)
# Out:
# Importing webbpsf
# Webbpsf version: 2.0.0
# Done with imports
# nrca3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca3_visit001_vgroup3109_exp00004_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00004: 8635 sources, 1171 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca3_visit001_vgroup3109_exp00007_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00007: 8100 sources, 1204 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca2_visit001_vgroup3109_exp00003_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00003: 6959 sources, 1064 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca2_visit001_vgroup3109_exp00007_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00007: 7710 sources, 1035 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca4_visit001_vgroup3109_exp00003_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00003: 11166 sources, 1491 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca2_visit001_vgroup3109_exp00002_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00002: 7697 sources, 1069 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca1_visit001_vgroup3109_exp00001_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00001: 6663 sources, 1059 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca3_visit001_vgroup3109_exp00005_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00005: 7469 sources, 1104 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca4_visit001_vgroup3109_exp00006_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00006: 8821 sources, 1280 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca3_visit001_vgroup3109_exp00001_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00001: 9006 sources, 1312 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca1_visit001_vgroup3109_exp00008_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00008: 7323 sources, 947 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca4_visit001_vgroup3109_exp00002_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00002: 11281 sources, 1267 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca3_visit001_vgroup3109_exp00008_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00008: 7671 sources, 1206 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca2_visit001_vgroup3109_exp00001_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00001: 8131 sources, 1060 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca2_visit001_vgroup3109_exp00006_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00006: 6883 sources, 1000 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca1_visit001_vgroup3109_exp00004_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00004: 6738 sources, 1025 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca1_visit001_vgroup3109_exp00003_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00003: 6937 sources, 1060 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca1_visit001_vgroup3109_exp00002_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00002: 6602 sources, 1054 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca3_visit001_vgroup3109_exp00003_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00003: 8412 sources, 1167 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca2_visit001_vgroup3109_exp00008_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00008: 7594 sources, 1046 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca3_visit001_vgroup3109_exp00002_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00002: 8976 sources, 1304 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca1_visit001_vgroup3109_exp00007_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00007: 7003 sources, 956 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca4_visit001_vgroup3109_exp00007_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00007: 8524 sources, 1199 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca1_visit001_vgroup3109_exp00006_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00006: 7192 sources, 1089 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca3_visit001_vgroup3109_exp00006_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00006: 7431 sources, 1084 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca1_visit001_vgroup3109_exp00005_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00005: 7105 sources, 1094 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca2_visit001_vgroup3109_exp00005_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00005: 7706 sources, 999 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca4_visit001_vgroup3109_exp00001_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00001: 10834 sources, 1267 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca4_visit001_vgroup3109_exp00004_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00004: 11085 sources, 1500 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca4_visit001_vgroup3109_exp00008_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00008: 9250 sources, 1214 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca4_visit001_vgroup3109_exp00005_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00005: 10240 sources, 1249 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrca2_visit001_vgroup3109_exp00004_daophot_basic.fits
# Filter F140M Module nrca Visit 001 Exposure 00004: 7106 sources, 1055 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb4_visit001_vgroup3109_exp00006_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00006: 10991 sources, 1291 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb1_visit001_vgroup3109_exp00004_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00004: 6809 sources, 981 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb3_visit001_vgroup3109_exp00001_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00001: 6906 sources, 1075 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb4_visit001_vgroup3109_exp00003_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00003: 7327 sources, 1214 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb4_visit001_vgroup3109_exp00001_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00001: 7821 sources, 1232 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb2_visit001_vgroup3109_exp00006_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00006: 7447 sources, 1107 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb3_visit001_vgroup3109_exp00003_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00003: 6993 sources, 1078 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb1_visit001_vgroup3109_exp00002_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00002: 7723 sources, 1020 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb1_visit001_vgroup3109_exp00001_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00001: 7268 sources, 1029 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb2_visit001_vgroup3109_exp00003_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00003: 7592 sources, 1055 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb3_visit001_vgroup3109_exp00006_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00006: 7949 sources, 1181 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb3_visit001_vgroup3109_exp00004_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00004: 7028 sources, 1071 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb4_visit001_vgroup3109_exp00008_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00008: 10392 sources, 1421 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb1_visit001_vgroup3109_exp00007_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00007: 7012 sources, 1016 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb2_visit001_vgroup3109_exp00002_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00002: 7579 sources, 1059 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb3_visit001_vgroup3109_exp00002_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00002: 7213 sources, 1074 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb2_visit001_vgroup3109_exp00007_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00007: 9673 sources, 1122 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb1_visit001_vgroup3109_exp00005_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00005: 6937 sources, 1015 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb1_visit001_vgroup3109_exp00006_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00006: 6773 sources, 1017 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb2_visit001_vgroup3109_exp00008_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00008: 7300 sources, 1127 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb3_visit001_vgroup3109_exp00005_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00005: 8466 sources, 1183 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb4_visit001_vgroup3109_exp00007_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00007: 9570 sources, 1442 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb2_visit001_vgroup3109_exp00004_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00004: 7490 sources, 1061 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb1_visit001_vgroup3109_exp00003_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00003: 6906 sources, 991 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb4_visit001_vgroup3109_exp00002_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00002: 7919 sources, 1242 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb1_visit001_vgroup3109_exp00008_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00008: 6999 sources, 999 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb3_visit001_vgroup3109_exp00008_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00008: 7301 sources, 1083 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb2_visit001_vgroup3109_exp00005_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00005: 7869 sources, 1106 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb4_visit001_vgroup3109_exp00004_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00004: 7723 sources, 1233 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb2_visit001_vgroup3109_exp00001_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00001: 7718 sources, 1065 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb4_visit001_vgroup3109_exp00005_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00005: 11210 sources, 1299 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F140M/f140m_nrcb3_visit001_vgroup3109_exp00007_daophot_basic.fits
# Filter F140M Module nrcb Visit 001 Exposure 00007: 7926 sources, 1071 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca4_visit001_vgroup3103_exp00007_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00007: 10739 sources, 1457 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca3_visit001_vgroup3103_exp00001_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00001: 12279 sources, 1629 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca1_visit001_vgroup3103_exp00004_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00004: 7832 sources, 1375 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca2_visit001_vgroup3103_exp00006_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00006: 8542 sources, 1419 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca3_visit001_vgroup3103_exp00004_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00004: 9031 sources, 1436 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca2_visit001_vgroup3103_exp00001_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00001: 9258 sources, 1286 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca3_visit001_vgroup3103_exp00008_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00008: 8828 sources, 1471 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca4_visit001_vgroup3103_exp00001_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00001: 14842 sources, 1520 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca4_visit001_vgroup3103_exp00003_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00003: 16272 sources, 1867 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca1_visit001_vgroup3103_exp00005_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00005: 8462 sources, 1539 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca1_visit001_vgroup3103_exp00003_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00003: 8135 sources, 1379 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca1_visit001_vgroup3103_exp00006_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00006: 8522 sources, 1522 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca1_visit001_vgroup3103_exp00007_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00007: 8117 sources, 1265 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca3_visit001_vgroup3103_exp00007_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00007: 8938 sources, 1486 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca2_visit001_vgroup3103_exp00002_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00002: 9212 sources, 1303 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca2_visit001_vgroup3103_exp00007_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00007: 9257 sources, 1508 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca2_visit001_vgroup3103_exp00003_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00003: 8492 sources, 1341 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca3_visit001_vgroup3103_exp00006_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00006: 8223 sources, 1343 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca1_visit001_vgroup3103_exp00002_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00002: 7722 sources, 1358 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca2_visit001_vgroup3103_exp00005_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00005: 8418 sources, 1426 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca3_visit001_vgroup3103_exp00002_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00002: 12104 sources, 1635 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca2_visit001_vgroup3103_exp00008_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00008: 9470 sources, 1535 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca3_visit001_vgroup3103_exp00005_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00005: 8013 sources, 1325 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca4_visit001_vgroup3103_exp00008_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00008: 10801 sources, 1467 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca1_visit001_vgroup3103_exp00001_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00001: 7824 sources, 1355 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca2_visit001_vgroup3103_exp00004_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00004: 8230 sources, 1331 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca4_visit001_vgroup3103_exp00002_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00002: 14882 sources, 1538 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca3_visit001_vgroup3103_exp00003_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00003: 9385 sources, 1434 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca4_visit001_vgroup3103_exp00006_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00006: 10589 sources, 1562 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca4_visit001_vgroup3103_exp00005_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00005: 10493 sources, 1568 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca1_visit001_vgroup3103_exp00008_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00008: 7890 sources, 1256 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrca4_visit001_vgroup3103_exp00004_daophot_basic.fits
# Filter F162M Module nrca Visit 001 Exposure 00004: 16298 sources, 1885 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb3_visit001_vgroup3103_exp00003_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00003: 8081 sources, 1214 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb1_visit001_vgroup3103_exp00005_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00005: 7668 sources, 1143 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb3_visit001_vgroup3103_exp00006_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00006: 11214 sources, 1512 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb3_visit001_vgroup3103_exp00001_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00001: 8085 sources, 1224 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb2_visit001_vgroup3103_exp00003_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00003: 8414 sources, 1213 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb4_visit001_vgroup3103_exp00007_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00007: 14552 sources, 1997 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb2_visit001_vgroup3103_exp00007_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00007: 8492 sources, 1305 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb1_visit001_vgroup3103_exp00004_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00004: 7963 sources, 1196 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb2_visit001_vgroup3103_exp00006_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00006: 8651 sources, 1285 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb4_visit001_vgroup3103_exp00003_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00003: 9549 sources, 1434 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb4_visit001_vgroup3103_exp00002_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00002: 9561 sources, 1464 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb3_visit001_vgroup3103_exp00005_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00005: 11178 sources, 1526 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb2_visit001_vgroup3103_exp00008_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00008: 8608 sources, 1325 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb1_visit001_vgroup3103_exp00006_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00006: 7864 sources, 1140 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb2_visit001_vgroup3103_exp00004_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00004: 8652 sources, 1232 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb2_visit001_vgroup3103_exp00005_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00005: 8677 sources, 1292 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb4_visit001_vgroup3103_exp00005_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00005: 13082 sources, 1689 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb4_visit001_vgroup3103_exp00008_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00008: 13905 sources, 1996 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb3_visit001_vgroup3103_exp00004_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00004: 8101 sources, 1215 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb1_visit001_vgroup3103_exp00007_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00007: 7764 sources, 1178 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb3_visit001_vgroup3103_exp00008_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00008: 8517 sources, 1293 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb4_visit001_vgroup3103_exp00006_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00006: 13166 sources, 1669 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb1_visit001_vgroup3103_exp00001_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00001: 8433 sources, 1316 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb3_visit001_vgroup3103_exp00007_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00007: 8787 sources, 1275 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb4_visit001_vgroup3103_exp00004_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00004: 8800 sources, 1425 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb1_visit001_vgroup3103_exp00002_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00002: 8403 sources, 1319 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb2_visit001_vgroup3103_exp00002_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00002: 8752 sources, 1195 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb3_visit001_vgroup3103_exp00002_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00002: 8054 sources, 1233 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb4_visit001_vgroup3103_exp00001_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00001: 9708 sources, 1497 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb1_visit001_vgroup3103_exp00008_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00008: 7999 sources, 1166 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb1_visit001_vgroup3103_exp00003_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00003: 8071 sources, 1214 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F162M/f162m_nrcb2_visit001_vgroup3103_exp00001_daophot_basic.fits
# Filter F162M Module nrcb Visit 001 Exposure 00001: 8836 sources, 1210 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca3_visit001_vgroup3105_exp00007_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00007: 8075 sources, 1719 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca2_visit001_vgroup3105_exp00004_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00004: 8023 sources, 1633 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca1_visit001_vgroup3105_exp00004_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00004: 7937 sources, 1767 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca3_visit001_vgroup3105_exp00004_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00004: 10502 sources, 1548 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca3_visit001_vgroup3105_exp00001_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00001: 15973 sources, 1711 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca4_visit001_vgroup3105_exp00003_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00003: 22952 sources, 1780 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca3_visit001_vgroup3105_exp00003_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00003: 10636 sources, 1550 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca2_visit001_vgroup3105_exp00007_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00007: 10325 sources, 2112 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca4_visit001_vgroup3105_exp00007_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00007: 11048 sources, 1623 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca2_visit001_vgroup3105_exp00001_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00001: 10009 sources, 1530 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca1_visit001_vgroup3105_exp00002_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00002: 7344 sources, 1698 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca1_visit001_vgroup3105_exp00003_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00003: 7914 sources, 1739 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca1_visit001_vgroup3105_exp00001_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00001: 7428 sources, 1701 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca1_visit001_vgroup3105_exp00005_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00005: 8860 sources, 2064 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca2_visit001_vgroup3105_exp00008_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00008: 10564 sources, 2095 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca4_visit001_vgroup3105_exp00002_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00002: 18950 sources, 1464 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca3_visit001_vgroup3105_exp00002_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00002: 15980 sources, 1711 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca4_visit001_vgroup3105_exp00004_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00004: 22779 sources, 1797 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca4_visit001_vgroup3105_exp00008_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00008: 11147 sources, 1631 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca2_visit001_vgroup3105_exp00005_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00005: 8589 sources, 1989 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca1_visit001_vgroup3105_exp00008_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00008: 8334 sources, 1696 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca1_visit001_vgroup3105_exp00006_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00006: 8969 sources, 2047 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca4_visit001_vgroup3105_exp00001_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00001: 19149 sources, 1501 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca4_visit001_vgroup3105_exp00005_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00005: 10372 sources, 1830 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca2_visit001_vgroup3105_exp00006_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00006: 8272 sources, 1978 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca1_visit001_vgroup3105_exp00007_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00007: 8364 sources, 1665 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca2_visit001_vgroup3105_exp00003_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00003: 7920 sources, 1643 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca3_visit001_vgroup3105_exp00008_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00008: 8129 sources, 1744 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca4_visit001_vgroup3105_exp00006_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00006: 10589 sources, 1802 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca3_visit001_vgroup3105_exp00005_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00005: 7351 sources, 1552 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca2_visit001_vgroup3105_exp00002_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00002: 9861 sources, 1503 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrca3_visit001_vgroup3105_exp00006_daophot_basic.fits
# Filter F182M Module nrca Visit 001 Exposure 00006: 7168 sources, 1544 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb3_visit001_vgroup3105_exp00003_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00003: 15718 sources, 1210 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb4_visit001_vgroup3105_exp00006_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00006: 14339 sources, 1786 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb4_visit001_vgroup3105_exp00008_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00008: 23257 sources, 1970 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb1_visit001_vgroup3105_exp00006_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00006: 11955 sources, 1191 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb3_visit001_vgroup3105_exp00007_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00007: 10181 sources, 1354 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb2_visit001_vgroup3105_exp00001_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00001: 9323 sources, 1317 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb3_visit001_vgroup3105_exp00008_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00008: 9999 sources, 1349 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb2_visit001_vgroup3105_exp00002_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00002: 9350 sources, 1330 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb2_visit001_vgroup3105_exp00007_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00007: 14417 sources, 1264 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb2_visit001_vgroup3105_exp00006_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00006: 10124 sources, 1253 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb4_visit001_vgroup3105_exp00002_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00002: 16720 sources, 1408 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb4_visit001_vgroup3105_exp00003_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00003: 10901 sources, 1403 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb1_visit001_vgroup3105_exp00004_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00004: 7505 sources, 1457 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb4_visit001_vgroup3105_exp00005_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00005: 14471 sources, 1781 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb3_visit001_vgroup3105_exp00005_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00005: 22070 sources, 1487 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb3_visit001_vgroup3105_exp00002_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00002: 10164 sources, 1241 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb3_visit001_vgroup3105_exp00006_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00006: 21976 sources, 1450 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb1_visit001_vgroup3105_exp00005_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00005: 11714 sources, 1201 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb1_visit001_vgroup3105_exp00002_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00002: 8103 sources, 1694 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb2_visit001_vgroup3105_exp00005_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00005: 10039 sources, 1242 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb2_visit001_vgroup3105_exp00008_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00008: 14242 sources, 1290 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb1_visit001_vgroup3105_exp00007_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00007: 10292 sources, 1283 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb4_visit001_vgroup3105_exp00004_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00004: 10919 sources, 1418 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb2_visit001_vgroup3105_exp00003_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00003: 10274 sources, 1292 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb2_visit001_vgroup3105_exp00004_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00004: 9831 sources, 1296 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb3_visit001_vgroup3105_exp00001_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00001: 10080 sources, 1222 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb3_visit001_vgroup3105_exp00004_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00004: 15930 sources, 1200 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb4_visit001_vgroup3105_exp00001_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00001: 16709 sources, 1403 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb1_visit001_vgroup3105_exp00003_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00003: 7492 sources, 1443 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb1_visit001_vgroup3105_exp00008_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00008: 10055 sources, 1262 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb1_visit001_vgroup3105_exp00001_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00001: 8185 sources, 1705 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F182M/f182m_nrcb4_visit001_vgroup3105_exp00007_daophot_basic.fits
# Filter F182M Module nrcb Visit 001 Exposure 00007: 23509 sources, 1971 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca2_visit001_vgroup3101_exp00006_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00006: 3054 sources, 683 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca4_visit001_vgroup3101_exp00001_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00001: 14869 sources, 909 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca4_visit001_vgroup3101_exp00004_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00004: 17930 sources, 855 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca3_visit001_vgroup3101_exp00006_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00006: 3300 sources, 705 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca2_visit001_vgroup3101_exp00002_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00002: 5848 sources, 709 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca3_visit001_vgroup3101_exp00004_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00004: 7045 sources, 732 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca3_visit001_vgroup3101_exp00007_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00007: 3721 sources, 778 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca1_visit001_vgroup3101_exp00001_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00001: 2953 sources, 710 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca1_visit001_vgroup3101_exp00008_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00008: 3703 sources, 654 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca2_visit001_vgroup3101_exp00007_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00007: 7497 sources, 766 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca3_visit001_vgroup3101_exp00003_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00003: 7263 sources, 743 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca3_visit001_vgroup3101_exp00002_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00002: 11359 sources, 817 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca2_visit001_vgroup3101_exp00008_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00008: 6146 sources, 746 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca4_visit001_vgroup3101_exp00003_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00003: 17923 sources, 860 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca2_visit001_vgroup3101_exp00001_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00001: 5521 sources, 695 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca1_visit001_vgroup3101_exp00002_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00002: 2989 sources, 703 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca4_visit001_vgroup3101_exp00002_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00002: 14734 sources, 870 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca1_visit001_vgroup3101_exp00003_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00003: 3183 sources, 685 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca2_visit001_vgroup3101_exp00003_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00003: 3772 sources, 720 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca3_visit001_vgroup3101_exp00008_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00008: 3884 sources, 780 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca3_visit001_vgroup3101_exp00001_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00001: 11635 sources, 816 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca4_visit001_vgroup3101_exp00006_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00006: 5718 sources, 878 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca1_visit001_vgroup3101_exp00006_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00006: 3260 sources, 774 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca1_visit001_vgroup3101_exp00004_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00004: 3139 sources, 690 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca4_visit001_vgroup3101_exp00008_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00008: 6921 sources, 855 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca2_visit001_vgroup3101_exp00005_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00005: 3061 sources, 688 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca1_visit001_vgroup3101_exp00007_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00007: 3661 sources, 648 after quality cuts
# nrca2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca2_visit001_vgroup3101_exp00004_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00004: 3711 sources, 709 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca4_visit001_vgroup3101_exp00005_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00005: 5833 sources, 888 after quality cuts
# nrca1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca1_visit001_vgroup3101_exp00005_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00005: 3281 sources, 764 after quality cuts
# nrca3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca3_visit001_vgroup3101_exp00005_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00005: 3346 sources, 684 after quality cuts
# nrca4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrca4_visit001_vgroup3101_exp00007_daophot_basic.fits
# Filter F187N Module nrca Visit 001 Exposure 00007: 6313 sources, 868 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb1_visit001_vgroup3101_exp00001_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00001: 3953 sources, 730 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb1_visit001_vgroup3101_exp00006_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00006: 9523 sources, 640 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb4_visit001_vgroup3101_exp00001_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00001: 12477 sources, 650 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb2_visit001_vgroup3101_exp00007_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00007: 11688 sources, 612 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb1_visit001_vgroup3101_exp00005_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00005: 9394 sources, 639 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb3_visit001_vgroup3101_exp00004_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00004: 13498 sources, 612 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb1_visit001_vgroup3101_exp00002_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00002: 3924 sources, 724 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb3_visit001_vgroup3101_exp00002_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00002: 7333 sources, 634 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb4_visit001_vgroup3101_exp00006_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00006: 11505 sources, 979 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb2_visit001_vgroup3101_exp00006_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00006: 6613 sources, 574 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb3_visit001_vgroup3101_exp00008_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00008: 5698 sources, 702 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb2_visit001_vgroup3101_exp00005_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00005: 6513 sources, 570 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb3_visit001_vgroup3101_exp00001_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00001: 7221 sources, 640 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb3_visit001_vgroup3101_exp00006_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00006: 18277 sources, 686 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb2_visit001_vgroup3101_exp00003_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00003: 6713 sources, 665 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb1_visit001_vgroup3101_exp00004_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00004: 3562 sources, 682 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb2_visit001_vgroup3101_exp00004_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00004: 6524 sources, 666 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb4_visit001_vgroup3101_exp00008_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00008: 19517 sources, 811 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb3_visit001_vgroup3101_exp00003_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00003: 13374 sources, 613 after quality cuts
# nrcb3
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb3_visit001_vgroup3101_exp00005_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00005: 18063 sources, 679 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb2_visit001_vgroup3101_exp00008_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00008: 11246 sources, 617 after quality cuts
# nrcb2
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb2_visit001_vgroup3101_exp00002_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00002: 5418 sources, 661 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb4_visit001_vgroup3101_exp00004_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00004: 6736 sources, 615 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb1_visit001_vgroup3101_exp00003_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00003: 3610 sources, 702 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb4_visit001_vgroup3101_exp00007_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00007: 19615 sources, 818 after quality cuts
# nrcb1
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb1_visit001_vgroup3101_exp00007_daophot_basic.fits
# Filter F187N Module nrcb Visit 001 Exposure 00007: 8295 sources, 671 after quality cuts
# nrcb4
# /orange/adamginsburg/jwst/w51/F187N/f187n_nrcb4_visit001_vgroup3101_exp00003_daophot_basic.fits
# ...
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup02105_exp00002_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00002: 2665 sources, 677 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup0210f_exp00003_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00003: 3041 sources, 885 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup0210f_exp00002_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00002: 3115 sources, 881 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup0210f_exp00003_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00003: 3041 sources, 885 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup0210f_exp00001_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00001: 3196 sources, 928 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup02105_exp00004_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00004: 2773 sources, 750 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup0210f_exp00001_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00001: 3196 sources, 928 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup0210f_exp00002_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00002: 3115 sources, 881 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup02105_exp00001_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00001: 2689 sources, 679 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup0210f_exp00004_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00004: 2982 sources, 885 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup02105_exp00002_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00002: 2665 sources, 677 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup02105_exp00003_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00003: 2674 sources, 731 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup02105_exp00003_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00003: 2674 sources, 731 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1000W/f1000w_mirimage_visit002_vgroup0210f_exp00004_daophot_basic.fits
# Filter F1000W Module mirimage Visit 002 Exposure 00004: 2982 sources, 885 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup0210h_exp00001_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00001: 2773 sources, 611 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup0210h_exp00003_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00003: 2758 sources, 606 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup02107_exp00003_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00003: 3472 sources, 887 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup0210h_exp00003_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00003: 2758 sources, 606 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup02107_exp00001_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00001: 3227 sources, 853 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup0210h_exp00002_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00002: 2701 sources, 600 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup0210h_exp00004_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00004: 2595 sources, 575 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup0210h_exp00002_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00002: 2701 sources, 600 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup02107_exp00001_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00001: 3227 sources, 853 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup02107_exp00002_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00002: 3388 sources, 886 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup02107_exp00003_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00003: 3472 sources, 887 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup02107_exp00004_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00004: 3340 sources, 886 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup02107_exp00004_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00004: 3340 sources, 886 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup0210h_exp00001_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00001: 2773 sources, 611 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup02107_exp00002_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00002: 3388 sources, 886 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit001_vgroup0210h_exp00004_daophot_basic.fits
# Filter F1280W Module mirimage Visit 001 Exposure 00004: 2595 sources, 575 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup0210h_exp00001_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00001: 3486 sources, 869 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup0210h_exp00003_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00003: 3517 sources, 896 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup02107_exp00003_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00003: 2697 sources, 707 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup0210h_exp00003_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00003: 3517 sources, 896 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup02107_exp00001_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00001: 2463 sources, 604 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup0210h_exp00002_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00002: 3446 sources, 922 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup0210h_exp00004_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00004: 3371 sources, 890 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup0210h_exp00002_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00002: 3446 sources, 922 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup02107_exp00001_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00001: 2463 sources, 604 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup02107_exp00002_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00002: 2523 sources, 592 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup02107_exp00003_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00003: 2697 sources, 707 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup02107_exp00004_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00004: 2670 sources, 663 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup02107_exp00004_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00004: 2670 sources, 663 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup0210h_exp00001_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00001: 3486 sources, 869 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup02107_exp00002_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00002: 2523 sources, 592 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F1280W/f1280w_mirimage_visit002_vgroup0210h_exp00004_daophot_basic.fits
# Filter F1280W Module mirimage Visit 002 Exposure 00004: 3371 sources, 890 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup0210j_exp00001_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00001: 1993 sources, 491 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup02109_exp00001_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00001: 1541 sources, 422 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup02109_exp00004_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00004: 1675 sources, 460 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup0210j_exp00003_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00003: 1952 sources, 497 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup02109_exp00004_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00004: 1675 sources, 460 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup02109_exp00003_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00003: 1562 sources, 408 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup02109_exp00001_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00001: 1541 sources, 422 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup0210j_exp00002_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00002: 2018 sources, 485 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup02109_exp00003_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00003: 1562 sources, 408 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup0210j_exp00002_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00002: 2018 sources, 485 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup02109_exp00002_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00002: 1580 sources, 422 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup0210j_exp00001_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00001: 1993 sources, 491 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup0210j_exp00004_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00004: 2058 sources, 522 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup02109_exp00002_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00002: 1580 sources, 422 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup0210j_exp00004_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00004: 2058 sources, 522 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit001_vgroup0210j_exp00003_daophot_basic.fits
# Filter F2100W Module mirimage Visit 001 Exposure 00003: 1952 sources, 497 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup0210j_exp00001_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00001: 1478 sources, 412 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup02109_exp00001_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00001: 1484 sources, 447 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup02109_exp00004_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00004: 1425 sources, 464 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup0210j_exp00003_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00003: 1489 sources, 463 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup02109_exp00004_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00004: 1425 sources, 464 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup02109_exp00003_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00003: 1443 sources, 461 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup02109_exp00001_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00001: 1484 sources, 447 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup0210j_exp00002_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00002: 1421 sources, 400 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup02109_exp00003_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00003: 1443 sources, 461 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup0210j_exp00002_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00002: 1421 sources, 400 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup02109_exp00002_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00002: 1423 sources, 447 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup0210j_exp00001_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00001: 1478 sources, 412 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup0210j_exp00004_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00004: 1452 sources, 403 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup02109_exp00002_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00002: 1423 sources, 447 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup0210j_exp00004_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00004: 1452 sources, 403 after quality cuts
# mirimage
# /orange/adamginsburg/jwst/w51/F2100W/f2100w_mirimage_visit002_vgroup0210j_exp00003_daophot_basic.fits
# Filter F2100W Module mirimage Visit 002 Exposure 00003: 1489 sources, 463 after quality cuts
