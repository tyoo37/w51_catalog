# %%
from astropy.table import Table
from astropy import units as u
from astropy.coordinates import SkyCoord
import os
import datetime

f560w_catalog = Table.read('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f560w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars.fits')

f770w_catalog = Table.read('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f770w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars.fits')
f1000w_catalog = Table.read('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f1000w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars.fits')
f1280w_catalog = Table.read('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f1280w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars.fits')
f2100w_catalog = Table.read('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f2100w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars.fits')  

print('last modified:', datetime.datetime.fromtimestamp(os.path.getmtime('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f560w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars.fits')))

#get the ra_shift and dec_shift from the two sky coordinates: 
#skycoord1 19:23:38.3599172947, 14:31:12.0058575961
#skycoord2 19:23:38.3708171143, 14:31:12.0143032307


skycoord1 = SkyCoord(ra='19:23:38.3599172947', dec='14:31:12.0058575961', frame='icrs', unit=(u.hourangle, u.deg))
skycoord2 = SkyCoord(ra='19:23:38.3708171143', dec='14:31:12.0143032307', frame='icrs', unit=(u.hourangle, u.deg))
ra_shift = skycoord2.ra - skycoord1.ra
dec_shift = skycoord2.dec - skycoord1.dec

# fix the offset by ra=0.2 arcsec
for catalog in [f560w_catalog, f770w_catalog, f1000w_catalog, f1280w_catalog, f2100w_catalog]:

    ra = catalog['skycoord'].ra
    ra_shifted = ra + ra_shift
    dec = catalog['skycoord'].dec
    dec_shifted = dec + dec_shift

    catalog['skycoord'] = SkyCoord(ra=ra_shifted, dec=dec_shifted, frame='icrs')

f560w_catalog.write('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f560w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars_fixed.fits', overwrite=True)
f770w_catalog.write('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f770w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars_fixed.fits', overwrite=True)
f1000w_catalog.write('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f1000w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars_fixed.fits', overwrite=True)
f1280w_catalog.write('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f1280w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars_fixed.fits', overwrite=True) 
f2100w_catalog.write('/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/catalogs/f2100w_mirimage_indivexp_merged_dao_after_merger_combined_with_satstars_fixed.fits', overwrite=True)
# Out:
# last modified: 2026-04-01 00:13:45
# WARNING: VerifyWarning: Keyword name 'fitter_maxiters' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'aperture_radius' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'progress_bar' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'pixscale_as' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'proposal_id' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'flux_err_prop' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
