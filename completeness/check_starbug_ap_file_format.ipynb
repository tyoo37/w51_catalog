# %%
from astropy.table import Table

dir = '/orange/adamginsburg/w51/TaehwaYoo/jwst_w51/F480M/pipeline'
filename = 'jw06151001001_03109_00001_nrcalong_cal_starbug2-ap.fits'
tab = Table.read(f'{dir}/{filename}', format='fits')
tab.pprint(max_width=-1)
# Out:
# Catalogue_Number     xcentroid          ycentroid              RA                DEC              sharpness            roundness1            roundness2           smoothness              flux                  eflux                   sky           flag       F480M                eF480M
# ---------------- ------------------ ------------------ ------------------ ------------------ ------------------- --------------------- ---------------------- ------------------ ---------------------- ---------------------- ---------------------- ---- ------------------ ---------------------
#              CN0 1305.9804177808473  4.066572207852781  290.9344699821215 14.530475756121175 0.46549587864394176   -0.6395086050033569    -0.3211720890630415 0.6923488077129888 1.6016194733308164e-05  1.215623386851267e-07 1.6355852494598366e-06    1 20.888601648630573  0.008209582565623895
# ...
